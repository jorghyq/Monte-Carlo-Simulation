# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cd ~/Dropbox/Project/python/Monte-Carlo-Simulation/BDS286/results15
# Out:
# /home/jorghyq/Dropbox/Project/python/Monte-Carlo-Simulation/BDS286/results15

# %%
E_dif = np.loadtxt("E_dif.txt",delimiter=',')
E_dif_av = np.loadtxt("E_dif_av.txt",delimiter=',')
E2_mean = np.loadtxt("E2_mean.txt",delimiter=',')
E_mean2 = np.loadtxt("E_mean2.txt",delimiter=',')

# %%
E2_max = np.max(E2_mean)
print E2_max
E2_norm = E2_mean/E2_max
#print E2_norm
plt.imshow(E2_mean/np.max(E2_mean))
# Out:
# 1310000000.0

# %%
plt.plot(E_dif[:,0])
plt.show()

# %%
plt.imshow(E_dif_av)
plt.show()

# %%
for i in range(E_dif.shape[1]):
    plt.plot(E_dif_av[:,i])
plt.show()

# %%
te = pd.read_pickle("totalenergy_final.pkl")

# %%
te['32']
# Out:
#         0      1      2      3      4      5      6      7      8
# 0   -2725  -5380  -8220 -11200 -13700 -16350 -18725 -22440 -24570
# 1    -280   -590   -700   -940  -1180  -1320  -1330  -1640  -2020
# 2   -6085  -8050 -10405 -13220 -15775 -17760 -19920 -23080 -25265
# 3    -575   -810   -760  -1280  -1550  -1640  -1770  -2320  -2295
# 4   -9855 -11170 -12995 -15600 -17425 -19980 -22335 -24680 -27030
# 5    -810  -1060  -1110  -1360  -1540  -1370  -1805  -2280  -2190
# 6  -13375 -14340 -15450 -18040 -20155 -21850 -22840 -26120 -27855
# 7   -1180   -950  -1275  -1600  -1760  -1730  -2370  -2440  -2675
# 8  -16750 -17580 -18175 -21460 -22380 -23820 -25455 -28120 -28505
# 9    -870  -1550  -1430  -1720  -2060  -2100  -2390  -2360  -2695
# 10 -20530 -21270 -21965 -24420 -25470 -26970 -27675 -30040 -29445
# 11  -1395  -1240  -1695  -1700  -1815  -2250  -2355  -2600  -3180
# 12 -24500 -24990 -25735 -27140 -27875 -29290 -29820 -31200 -30495
# 13  -1740  -2040  -2175  -2440  -3060  -2200  -3165  -3280  -3130
# 14 -28045 -28490 -29260 -29700 -30520 -31280 -31920 -33920 -31250
# 15  -2275  -1980  -1965  -2120  -2790  -2520  -3510  -3160  -3290
# 16 -31405 -31900 -32235 -33300 -33615 -33930 -34615 -34680 -33330
# 17  -2270  -2590  -2525  -3120  -3305  -3080  -3815  -3600  -3745
# 18 -34905 -35000 -35090 -35540 -35780 -36670 -36240 -36440 -33745
# 19  -2485  -3010  -3040  -3220  -3125  -3660  -3505  -3760  -3905
# 20 -37070 -37970 -37300 -37780 -38120 -37670 -38310 -35520 -33795
# 21  -2505  -2910  -3425  -3460  -3420  -3490  -3450  -3800  -4015
# 22 -39625 -39560 -40170 -40600 -38940 -39150 -39470 -36320 -33750
# 23  -2935  -3020  -3445  -3360  -3895  -4600  -3830  -4360  -4510
# 24 -41410 -42130 -40620 -41800 -39855 -40410 -39615 -36000 -34735
#
# [25 rows x 9 columns]
